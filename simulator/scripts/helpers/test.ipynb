# %%
import importlib
import type_util
importlib.reload(type_util)
# Out:
# <module 'type_util' from 'C:\\Users\\njona\\WebstormProjects\\chArm-interpreter\\simulator\\scripts\\helpers\\type_util.py'>

# %%
print(type_util.parse_type('&mut ()'))
# Out:
# normalized:  mut ()*)
# m
